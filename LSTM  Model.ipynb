# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Flatten
# Out:
# WARNING:tensorflow:From C:\Users\varsh\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
def prepare_data(timeseries_data, n_features):
	X, y =[],[]
	for i in range(len(timeseries_data)):
		# find the end of this pattern
		end_ix = i + n_features
		# check if we are beyond the sequence
		if end_ix > len(timeseries_data)-1:
			break
		# gather input and output parts of the pattern
		seq_x, seq_y = timeseries_data[i:end_ix], timeseries_data[end_ix]
		X.append(seq_x)
		y.append(seq_y)
	return np.array(X), np.array(y)

# %%
# Out:
#                                                       0
# 0     ï»¿case_id,subjectid,casestart,caseend,anestar...
# 1     1,5955,0,11542,-552,10848,1668,10368,-236220,6...
# 2     2,2487,0,15741,-1039,14921,1721,14621,-221160,...
# 3     3,2861,0,4394,-590,4210,1090,3010,-218640,4056...
# 4     4,1903,0,20990,-778,20222,2522,17822,-201120,5...
# ...                                                 ...
# 6384  6384,5583,0,15248,-260,15640,2140,14140,-21534...
# 6385  6385,2278,0,20643,-544,20996,2396,19496,-22560...
# 6386  6386,4045,0,19451,-667,19133,3533,18233,-20046...
# 6387  6387,5230,0,12025,-550,12830,1730,11030,-22776...
# 6388  6388,1306,0,10249,-79,10121,2321,9221,-312060,...
#
# [6389 rows x 1 columns]

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming 'clinical data 2 processed.csv' contains your dataset
data = pd.read_csv('clinical data 2 processed.csv')

# Split the data into input (X) and output (y) samples
X = data.drop(columns=['intraop_eph'])
y = data['intraop_eph']


# Assuming 'data' is your pandas DataFrame
X = data.drop(columns=['intraop_eph'])
y = data['intraop_eph']

# Convert non-numeric values to numeric values
X = X.astype(float)
y = y.astype(float)

# Convert X to a numpy array
X = X.to_numpy()

scaler = StandardScaler()

print(df)

# Reshape the input data to be 3D for LSTM input [samples, timesteps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# Create the LSTM model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Fit the model
model.fit(X, y, epochs=200, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 20
#      17 y = data['intraop_eph']
#      19 # Convert non-numeric values to numeric values
# ---> 20 X = X.astype(float)
#      21 y = y.astype(float)
#      23 # Convert X to a numpy array
#
# File C:\Anaconda\envs\Jupyter\Lib\site-packages\pandas\core\generic.py:6637, in NDFrame.astype(self, dtype, copy, errors)
#    6631     results = [
#    6632         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6633     ]
#    6635 else:
#    6636     # else, only a single dtype is given
# -> 6637     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6638     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6639     return res.__finalize__(self, method="astype")
#
# ...

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming 'clinical data 2 processed.csv' contains your dataset
data = pd.read_csv('clinical data 2 processed.csv')

# Split the data into input (X) and output (y) samples
X = data.drop(columns=['intraop_eph'])
y = data['intraop_eph']


# Assuming 'data' is your pandas DataFrame
X = data.drop(columns=['intraop_eph'])
y = data['intraop_eph']

# Convert non-numeric values to NaN for each column
for col in X.columns:
    X[col] = pd.to_numeric(X[col], errors='coerce')

y = pd.to_numeric(y, errors='coerce')

# Fill NaN values with a specific value (e.g., 0)
X.fillna(0, inplace=True)
y.fillna(0, inplace=True)

# Convert X to a numpy array
X = X.to_numpy()

scaler = StandardScaler()

print(df)

# Reshape the input data to be 3D for LSTM input [samples, timesteps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# Create the LSTM model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Fit the model
model.fit(X, y, epochs=200, verbose=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 20
#      17 y = data['intraop_eph']
#      19 # Convert non-numeric values to NaN
# ---> 20 X = pd.to_numeric(X, errors='coerce')
#      21 y = pd.to_numeric(y, errors='coerce')
#      23 # Fill NaN values with a specific value (e.g., 0)
#
# File C:\Anaconda\envs\Jupyter\Lib\site-packages\pandas\core\tools\numeric.py:206, in to_numeric(arg, errors, downcast, dtype_backend)
#     204     values = np.array([arg], dtype="O")
#     205 elif getattr(arg, "ndim", 1) > 1:
# --> 206     raise TypeError("arg must be a list, tuple, 1-d array, or Series")
#     207 else:
#     208     values = arg
#
# TypeError: arg must be a list, tuple, 1-d array, or Series

# %%
# Out:
# WARNING:tensorflow:From C:\Users\varsh\AppData\Roaming\Python\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#
# WARNING:tensorflow:From C:\Users\varsh\AppData\Roaming\Python\Python311\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From C:\Users\varsh\AppData\Roaming\Python\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/200
# WARNING:tensorflow:From C:\Users\varsh\AppData\Roaming\Python\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# ...

# %%
X_new = np.random.randn(1, X.shape[1], 1)  # New input sequence
y_pred =Sequential()(data.drop(columns=['intraop_eph']))
print("Predicted value:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 X_new = np.random.randn(1, X.shape[1], 1)  # New input sequence
#       2 y_pred =Sequential()(data.drop(columns=['intraop_eph']))
#       3 print("Predicted value:", y_pred)
#
# NameError: name 'np' is not defined

# %%
X_new = np.random.randn(1, 10, 1)  # New input sequence
y_pred = model.predict(X_new)
print("Predicted value:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 X_new = np.random.randn(1, 10, 1)  # New input sequence
# ----> 2 y_pred = model.predict(X_new)
#       3 print("Predicted value:", y_pred)
#
# NameError: name 'model' is not defined

# %%
import numpy as np
from keras.models import Sequential
from keras.layers import LSTM, Dense
import pandas as pd
from sklearn.preprocessing import StandardScaler

# Assuming 'clinical data 2 processed.csv' contains your dataset
data = pd.read_csv('clinical data 2 processed.csv')

# Split the data into input (X) and output (y) samples
X = data.drop(columns=['intraop_eph'])
y = data['intraop_eph']


# Assuming 'data' is your pandas DataFrame
X = data.drop(columns=['intraop_eph'])
y = data['intraop_eph']

# Convert non-numeric values to NaN for each column
for col in X.columns:
    X[col] = pd.to_numeric(X[col], errors='coerce')

y = pd.to_numeric(y, errors='coerce')

# Fill NaN values with a specific value (e.g., 0)
X.fillna(0, inplace=True)
y.fillna(0, inplace=True)

# Convert X to a numpy array
X = X.to_numpy()

scaler = StandardScaler()

print(df)

# Reshape the input data to be 3D for LSTM input [samples, timesteps, features]
X = X.reshape(X.shape[0], X.shape[1], 1)

# Create the LSTM model
model = Sequential()
model.add(LSTM(50, activation='relu', input_shape=(X.shape[1], 1)))
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')

# Fit the model
model.fit(X, y, epochs=200, verbose=1)

# %%
# prediction
X_new = np.random.randn(1, 1, 1)  # New input sequence
y_pred = model.predict(X_new)
print("Predicted value:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 3
#       1 # prediction
#       2 X_new = np.random.randn(1, 10, 1)  # New input sequence
# ----> 3 y_pred = model.predict(X_new)
#       4 print("Predicted value:", y_pred)
#
# NameError: name 'model' is not defined

# %%
# prediction
X_new = np.random.randn(1, 1, 1)  # New input sequence
y_pred = Sequential()(data.drop(columns=['intraop_eph']))
print("Predicted value:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # prediction
# ----> 2 X_new = np.random.randn(1, 1, 1)  # New input sequence
#       3 y_pred = Sequential()(data.drop(columns=['intraop_eph']))
#       4 print("Predicted value:", y_pred)
#
# NameError: name 'np' is not defined

# %%
# Assuming 'model' is your trained Keras model and 'data' is your input data
y_pred = model.predict(data.drop(columns=['intraop_eph']))
print("Predicted value:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 # Assuming 'model' is your trained Keras model and 'data' is your input data
# ----> 2 y_pred = model.predict(data.drop(columns=['intraop_eph']))
#       3 print("Predicted value:", y_pred)
#
# NameError: name 'model' is not defined

# %%
y_pred = Sequential.predict(data.drop(columns=['intraop_eph']))
print("Predicted value:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 y_pred = Sequential.predict(data.drop(columns=['intraop_eph']))
#       2 print("Predicted value:", y_pred)
#
# NameError: name 'Sequential' is not defined

# %%
y_pred = Sequential()(data.drop(columns=['intraop_eph']))
print("Predicted value:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 y_pred = Sequential()(data.drop(columns=['intraop_eph']))
#       2 print("Predicted value:", y_pred)
#
# NameError: name 'Sequential' is not defined

# %%
y_pred = Sequential()(data.drop(columns=['intraop_eph']))
print("Predicted value:", y_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 y_pred = Sequential()(data.drop(columns=['intraop_eph']))
#       2 print("Predicted value:", y_pred)
#
# NameError: name 'Sequential' is not defined

# %%
import matplotlib.pyplot as plt

# %%
day_new=np.arange(1,10)
day_pred=np.arange(10,20)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 day_new=np.arange(1,10)
#       2 day_pred=np.arange(10,20)
#
# NameError: name 'np' is not defined

# %%
y_pred = Sequential()(data)

# Plot the original time series data
plt.plot('clinical data 2 processed.csv', label='Original Data')

# Plot the predicted values
plt.plot(y_pred, label='Predicted Data')

# Customize the plot
plt.xlabel('Time')
plt.ylabel('Value')
plt.title('LSTM Model Prediction')
plt.legend()
plt.show()
